# %%
from qiskit import QuantumCircuit, assemble
from qiskit.visualization import array_to_latex, plot_histogram
from qiskit_aer import AerSimulator

# %% [markdown]
# ## Create the circuit

# %%
# Design a 2-qubit circuit
qc = QuantumCircuit(2)

# Apply H-gate to the first:
qc.h(0)
# Apply a CNOT:
qc.cx(0,1)
qc.draw('mpl')

# %% [markdown]
# ## Simulate and plot probabilties

# %%
simulator = AerSimulator()
qc.save_statevector()
qobj = assemble(qc)
result = simulator.run(qobj).result()

# Print the statevector neatly:
final_state = result.get_statevector()
array_to_latex(final_state, prefix="\\text{Statevector = }")
plot_histogram(result.get_counts())
# Out:
# /var/folders/3m/pc44t30x60gd3bj_3f670_yw0000gn/T/ipykernel_23803/3643770966.py:4: DeprecationWarning: Using a qobj for run() is deprecated as of qiskit-aer 0.14 and will be removed no sooner than 3 months from that release date. Transpiled circuits should now be passed directly using `backend.run(circuits, **run_options).
#   result = simulator.run(qobj).result()

# %%
print('Remark: Only |00> and |11> present with equal probabilities. Implicates Bell state (phi^+)')
# Out:
# Remark: Only |00> and |11> present with equal probabilities. Implicates Bell state (phi^+)
